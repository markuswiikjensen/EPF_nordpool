# %%
import pandas as pd
import os

folder_path = '/Users/markuswiikjensen/Desktop/Master-Data/NO3_data'  # replace with the path to your folder
dfs = []  # initialize an empty list to store the DataFrames

for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    dfs.append(file_path)  # append the DataFrame to the list

# %%
len(dfs)
# Out:
# 11

# %%
dfs
# Out:
# ['/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/net_exchange.csv',
#  '/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/prices_brent_lng_updated.csv',
#  '/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/.DS_Store',
#  '/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/da_production_prognosis.csv',
#  '/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/electricity_consumption.csv',
#  '/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/elspot_prices_dt_interpolated.csv',
#  '/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/weather_averaged_preprocessed_NO3.csv',
#  '/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/reservoir_levels.csv',
#  '/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/prices_osebx_updated.csv',
#  '/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/wind_settlement.csv',
#  '/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/electricity_production.csv']

# %%
df1=pd.read_csv('/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/elspot_prices_dt_interpolated.csv')
df1.set_index('datetime', inplace=True)
df1 = df1[~df1.index.duplicated()]

# %%
df1=df1['Molde']
df1 = df1.to_frame('price')

# %%
df2=pd.read_csv('/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/electricity_consumption.csv')
df2.set_index('datetime', inplace=True)
df2 = df2[~df2.index.duplicated()]

# %%
df2=df2['NO3']
df2.sort_index(ascending=True, inplace=True)
df2 = df2.to_frame('consumption')

# %%
df3=pd.read_csv('/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/electricity_production.csv')
df3.set_index('datetime', inplace=True)
df3 = df3[~df3.index.duplicated()]

# %%
df3=df3['NO3']
df3.sort_index(ascending=True, inplace=True)
df3 = df3.to_frame('production')

# %%
df4=pd.read_csv('/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/da_production_prognosis.csv')
df4.set_index('datetime', inplace=True)
df4 = df4[~df4.index.duplicated()]

# %%
df4=df4['NO3']
df4.sort_index(ascending=True, inplace=True)
df4 = df4.to_frame('da_production')

# %%
df5=pd.read_csv('/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/net_exchange.csv')
df5.set_index('datetime', inplace=True)
df5 = df5[~df5.index.duplicated()]

# %%
df5.sort_index(ascending=True, inplace=True)
filtered_cols = df5.columns[df5.columns.str.contains('NO3')]
df5=df5[filtered_cols]
df5=df5.rename(columns={'NO1_NO3': 'exchange_NO1_NO3', 'NO3_NO4':'exchange_NO3_NO4', 'NO3_NO5':'exchange_NO3_NO5', 'NO3_SE2':'exchange_NO3_SE2'})
df5
# Out:
#                      exchange_NO1_NO3  exchange_NO3_NO4  exchange_NO3_NO5  \
# datetime
# 2019-12-30 00:00:00            -156.0              28.0              21.0
# 2019-12-30 01:00:00            -156.0               5.0             143.0
# 2019-12-30 02:00:00            -204.0             -80.0             193.0
# 2019-12-30 03:00:00            -204.0            -127.0             171.0
# 2019-12-30 04:00:00            -211.0            -133.0             158.0
# ...                               ...               ...               ...
# 2023-04-07 19:00:00               NaN               NaN               NaN
# 2023-04-07 20:00:00               NaN               NaN               NaN
# 2023-04-07 21:00:00               NaN               NaN               NaN
# 2023-04-07 22:00:00               NaN               NaN               NaN
# 2023-04-07 23:00:00               NaN               NaN               NaN
#
#                      exchange_NO3_SE2
# datetime
# 2019-12-30 00:00:00             705.0
# 2019-12-30 01:00:00             793.0
# 2019-12-30 02:00:00             756.0
# 2019-12-30 03:00:00             723.0
# 2019-12-30 04:00:00             742.0
# ...                               ...
# 2023-04-07 19:00:00               NaN
# 2023-04-07 20:00:00               NaN
# 2023-04-07 21:00:00               NaN
# 2023-04-07 22:00:00               NaN
# 2023-04-07 23:00:00               NaN
#
# [28680 rows x 4 columns]

# %%
df7=pd.read_csv('/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/weather_averaged_preprocessed_NO3.csv')
# Convert the 'date' column to datetime
df7['referenceTime'] = pd.to_datetime(df7['referenceTime'])

# Extract the date part and assign it back to the 'date' column
df7['datetime'] = df7['referenceTime'].dt.date
df7['datetime'] = pd.to_datetime(df7['datetime'])
df7.set_index('datetime', inplace=True)
df7 = df7[~df7.index.duplicated()]
df7=df7.rename(columns={'mean(air_temperature P1D)': 'air_temperature', 'mean(wind_speed P1D)': 'wind_speed','sum(precipitation_amount P1D)':'precipitation_amount' })
df7.drop('referenceTime', axis=1, inplace=True)
df7 = df7.resample('H').ffill()

# %%
df8=pd.read_csv('/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/reservoir_levels.csv')
# Convert the 'date' column to datetime
df8['datetime'] = pd.to_datetime(df8['Year/Week'] + '-1', format='%Y/%U-%w')
df8.set_index('datetime', inplace=True)
df8 = df8[~df8.index.duplicated()]
# 1. Convert string dates to datetime objects
start_date = pd.to_datetime('2019-12-29')
end_date = pd.to_datetime('2023-04-01')

# 2. Create new index using pd.date_range()
new_index = pd.date_range(start=start_date, end=end_date, freq='H')

# 3. Reindex DataFrame using new index
df8 = df8.reindex(pd.to_datetime(new_index))

df8 = df8.fillna(method='backfill')
df8 =df8.fillna(method='ffill')
df8=df8[['Capacity_GWh', 'Levels_GWh']]
df8=df8.rename(columns={'Capacity_GWh':'reservoir_capacity', 'Levels_GWh': 'reservoir_levels'})

# %%
df9=pd.read_csv('/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/prices_brent_lng_updated.csv')
df9['datetime'] = pd.to_datetime(df9['Date'])
df9.set_index('datetime', inplace=True, drop=True)
df9 = df9[~df9.index.duplicated()]
df9 = df9.resample('H').ffill()
df9=df9[['BZ=F','NG=F']]
df9=df9.rename(columns={'BZ=F':'oil_price','NG=F':'gas_price' })

# %%
df10=pd.read_csv('/Users/markuswiikjensen/Desktop/Master-Data/NO3_data/prices_osebx_updated.csv')
df10['datetime'] = pd.to_datetime(df10['Date'])
df10.set_index('datetime', inplace=True, drop=True)
df10 = df10[~df10.index.duplicated()]
df10 = df10.resample('H').ffill()
df10 = df10.rename(columns={'Adj Close': 'osebx_price'})
df10 =df10['osebx_price']
df10 = df10.to_frame('osebx_price')

# %%
dfs = [df1, df2, df3, df4, df5, df7, df8, df9, df10]
df=df1.join(df2, on=df1.index, how='left')
df=df.join(df3,  on=df1.index, how='left')
df=df.join(df4,  on=df1.index, how='left')
df=df.join(df5,  on=df1.index, how='left')

# %%
df.index = pd.to_datetime(df.index, format='%Y-%m-%d %H:%M:%S')

# %%
df=df.join(df7,  on='datetime', how='left')
df=df.join(df8,  on='datetime', how='left')
df=df.join(df9,  on='datetime', how='left')
df=df.join(df10,  on='datetime', how='left')

# %%
df
# Out:
#                         price  consumption  production  da_production  \
# datetime
# 2020-01-01 00:00:00   28387.0       2878.0      2185.0         2199.0
# 2020-01-01 01:00:00   28062.0       3130.0      2729.0         2690.0
# 2020-01-01 02:00:00   27519.0       3016.0      2569.0         2530.0
# 2020-01-01 03:00:00   27144.0       2945.0      2411.0         2382.0
# 2020-01-01 04:00:00   27164.0       3032.0      2323.0         2313.0
# ...                       ...          ...         ...            ...
# 2023-04-17 19:00:00  117379.0          NaN         NaN            NaN
# 2023-04-17 20:00:00  102641.0          NaN         NaN            NaN
# 2023-04-17 21:00:00   93618.0          NaN         NaN            NaN
# 2023-04-17 22:00:00   79850.0          NaN         NaN            NaN
# 2023-04-17 23:00:00   66834.0          NaN         NaN            NaN
#
#                      exchange_NO1_NO3  exchange_NO3_NO4  exchange_NO3_NO5  \
# datetime
# 2020-01-01 00:00:00              19.0             298.0             -41.0
# 2020-01-01 01:00:00             146.0             646.0            -114.0
# 2020-01-01 02:00:00              83.0             599.0             -34.0
# 2020-01-01 03:00:00              50.0             578.0             -23.0
# 2020-01-01 04:00:00              -6.0             502.0              -4.0
# ...                               ...               ...               ...
# 2023-04-17 19:00:00               NaN               NaN               NaN
# 2023-04-17 20:00:00               NaN               NaN               NaN
# 2023-04-17 21:00:00               NaN               NaN               NaN
# 2023-04-17 22:00:00               NaN               NaN               NaN
# 2023-04-17 23:00:00               NaN               NaN               NaN
#
#                      exchange_NO3_SE2  air_temperature  wind_speed  \
# datetime
# 2020-01-01 00:00:00             454.0         4.614063    9.209677
# 2020-01-01 01:00:00              15.0         4.614063    9.209677
# 2020-01-01 02:00:00             -35.0         4.614063    9.209677
# 2020-01-01 03:00:00              29.0         4.614063    9.209677
# 2020-01-01 04:00:00             205.0         4.614063    9.209677
# ...                               ...              ...         ...
# 2023-04-17 19:00:00               NaN              NaN         NaN
# 2023-04-17 20:00:00               NaN              NaN         NaN
# 2023-04-17 21:00:00               NaN              NaN         NaN
# 2023-04-17 22:00:00               NaN              NaN         NaN
# 2023-04-17 23:00:00               NaN              NaN         NaN
#
#                      precipitation_amount  reservoir_capacity  \
# datetime
# 2020-01-01 00:00:00             15.906897             87301.0
# 2020-01-01 01:00:00             15.906897             87301.0
# 2020-01-01 02:00:00             15.906897             87301.0
# 2020-01-01 03:00:00             15.906897             87301.0
# 2020-01-01 04:00:00             15.906897             87301.0
# ...                                   ...                 ...
# 2023-04-17 19:00:00                   NaN                 NaN
# 2023-04-17 20:00:00                   NaN                 NaN
# 2023-04-17 21:00:00                   NaN                 NaN
# 2023-04-17 22:00:00                   NaN                 NaN
# 2023-04-17 23:00:00                   NaN                 NaN
#
#                      reservoir_levels  oil_price  gas_price  osebx_price
# datetime
# 2020-01-01 00:00:00           55923.0        NaN        NaN          NaN
# 2020-01-01 01:00:00           55923.0        NaN        NaN          NaN
# 2020-01-01 02:00:00           55923.0        NaN        NaN          NaN
# 2020-01-01 03:00:00           55923.0        NaN        NaN          NaN
# 2020-01-01 04:00:00           55923.0        NaN        NaN          NaN
# ...                               ...        ...        ...          ...
# 2023-04-17 19:00:00               NaN        NaN        NaN          NaN
# 2023-04-17 20:00:00               NaN        NaN        NaN          NaN
# 2023-04-17 21:00:00               NaN        NaN        NaN          NaN
# 2023-04-17 22:00:00               NaN        NaN        NaN          NaN
# 2023-04-17 23:00:00               NaN        NaN        NaN          NaN
#
# [28872 rows x 16 columns]

# %%
df=df.fillna(method='backfill')
df=df.dropna()
df
# Out:
#                         price  consumption  production  da_production  \
# datetime
# 2020-01-01 00:00:00   28387.0       2878.0      2185.0         2199.0
# 2020-01-01 01:00:00   28062.0       3130.0      2729.0         2690.0
# 2020-01-01 02:00:00   27519.0       3016.0      2569.0         2530.0
# 2020-01-01 03:00:00   27144.0       2945.0      2411.0         2382.0
# 2020-01-01 04:00:00   27164.0       3032.0      2323.0         2313.0
# ...                       ...          ...         ...            ...
# 2023-03-29 20:00:00  144605.0       3642.0      2602.0         2672.0
# 2023-03-29 21:00:00  115553.0       3656.0      2689.0         2698.0
# 2023-03-29 22:00:00   99660.0       3679.0      2760.0         2738.0
# 2023-03-29 23:00:00   73353.0       3619.0      2721.0         2708.0
# 2023-03-30 00:00:00  101233.0       3781.0      2449.0         2588.0
#
#                      exchange_NO1_NO3  exchange_NO3_NO4  exchange_NO3_NO5  \
# datetime
# 2020-01-01 00:00:00              19.0             298.0             -41.0
# 2020-01-01 01:00:00             146.0             646.0            -114.0
# 2020-01-01 02:00:00              83.0             599.0             -34.0
# 2020-01-01 03:00:00              50.0             578.0             -23.0
# 2020-01-01 04:00:00              -6.0             502.0              -4.0
# ...                               ...               ...               ...
# 2023-03-29 20:00:00             179.0            1190.0              39.0
# 2023-03-29 21:00:00             190.0            1168.0              64.0
# 2023-03-29 22:00:00             239.0            1202.0               6.0
# 2023-03-29 23:00:00             251.0            1206.0             -64.0
# 2023-03-30 00:00:00             216.0            1277.0            -142.0
#
#                      exchange_NO3_SE2  air_temperature  wind_speed  \
# datetime
# 2020-01-01 00:00:00             454.0         4.614063    9.209677
# 2020-01-01 01:00:00              15.0         4.614063    9.209677
# 2020-01-01 02:00:00             -35.0         4.614063    9.209677
# 2020-01-01 03:00:00              29.0         4.614063    9.209677
# 2020-01-01 04:00:00             205.0         4.614063    9.209677
# ...                               ...              ...         ...
# 2023-03-29 20:00:00             -80.0        -6.782222    2.251613
# 2023-03-29 21:00:00             -87.0        -6.782222    2.251613
# 2023-03-29 22:00:00             -55.0        -6.782222    2.251613
# 2023-03-29 23:00:00              25.0        -6.782222    2.251613
# 2023-03-30 00:00:00             278.0        -7.146457    3.235484
#
#                      precipitation_amount  reservoir_capacity  \
# datetime
# 2020-01-01 00:00:00             15.906897             87301.0
# 2020-01-01 01:00:00             15.906897             87301.0
# 2020-01-01 02:00:00             15.906897             87301.0
# 2020-01-01 03:00:00             15.906897             87301.0
# 2020-01-01 04:00:00             15.906897             87301.0
# ...                                   ...                 ...
# 2023-03-29 20:00:00              0.005128             87301.0
# 2023-03-29 21:00:00              0.005128             87301.0
# 2023-03-29 22:00:00              0.005128             87301.0
# 2023-03-29 23:00:00              0.005128             87301.0
# 2023-03-30 00:00:00              0.007692             87301.0
#
#                      reservoir_levels   oil_price  gas_price  osebx_price
# datetime
# 2020-01-01 00:00:00           55923.0  582.464933  18.656462   941.270020
# 2020-01-01 01:00:00           55923.0  582.464933  18.656462   941.270020
# 2020-01-01 02:00:00           55923.0  582.464933  18.656462   941.270020
# 2020-01-01 03:00:00           55923.0  582.464933  18.656462   941.270020
# 2020-01-01 04:00:00           55923.0  582.464933  18.656462   941.270020
# ...                               ...         ...        ...          ...
# 2023-03-29 20:00:00           53981.0  815.527912  20.742414  1168.589966
# 2023-03-29 21:00:00           53981.0  815.527912  20.742414  1168.589966
# 2023-03-29 22:00:00           53981.0  815.527912  20.742414  1168.589966
# 2023-03-29 23:00:00           53981.0  815.527912  20.742414  1168.589966
# 2023-03-30 00:00:00           53981.0  826.997384  21.950330  1184.660034
#
# [28417 rows x 16 columns]

# %%
df.to_csv('NO3_preprocessed')
